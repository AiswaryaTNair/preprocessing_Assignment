# %% [markdown]
# # Case study on Pre-processing
# 1. Load the dataset into python environment
# 2. Make ‘PassengerId’ as the index column
# 3. Check the basic details of the dataset
# 4. Fill in all the missing values present in all the columns in the dataset
# 5. Check and handle outliers in at least 3 columns in the dataset
# 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Load the dataset into python environment

# %%
titanic_data=pd.read_csv(r'C:\\Users\\We care\\titanic_dataset.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
titanic_data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Oreskovic, Mr. Luka  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare        Cabin  \
# ...

# %%
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_data.isnull().sum().sum()
# Out:
# 866

# %%
titanic_data.isnull().values.any()
# Out:
# True

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
# missing values are in 3 columns they are age, cabin and embarked.

# %%
titanic_data['Age'].fillna(titanic_data['Age'].mean(),inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data['Cabin'].fillna(('Unknown'),inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
titanic_data['Embarked'].mode
# Out:
# <bound method Series.mode of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
titanic_data['Embarked'].fillna(('S'),inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the dataset

# %%
plt.boxplot(titanic_data['Fare'])
plt.title('box plot of Fare')

# %%
Q1= np.percentile(titanic_data['Fare'], 25, interpolation='midpoint')
Q2= np.percentile(titanic_data['Fare'], 50, interpolation='midpoint')
Q3= np.percentile(titanic_data['Fare'], 75, interpolation='midpoint')
IQR=Q3-Q1
Low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR

# %%
outlier=[]
for x in titanic_data['Fare']:
    if((x>Up_lim) or (x<Low_lim)):
        outlier.append(x)

# %%
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %%
ind1=titanic_data['Fare']>Up_lim
titanic_data.loc[ind1].index
titanic_data.drop(titanic_data.loc[ind1].index,inplace=True)

# %%
plt.boxplot(titanic_data['Fare'])
plt.title('box plot of Fare')
# Out:
# Text(0.5, 1.0, 'box plot of Fare')

# %%
plt.boxplot(titanic_data['Age'])
plt.title('box plot of Age')
# Out:
# Text(0.5, 1.0, 'box plot of Age')

# %%
Q1= np.percentile(titanic_data['Age'], 25, interpolation='midpoint')
Q2= np.percentile(titanic_data['Age'], 50, interpolation='midpoint')
Q3= np.percentile(titanic_data['Age'], 75, interpolation='midpoint')
IQR=Q3-Q1
Low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR

# %%
outlier=[]
for x in titanic_data['Age']:
    if((x>Up_lim) or (x<Low_lim)):
        outlier.append(x)

# %%
outlier
# Out:
# [54.0,
#  2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  3.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  3.0,
#  2.0,
#  59.0,
#  54.0,
#  62.0,
#  3.0,
#  65.0,
#  54.0,
#  61.0,
#  2.0,
#  3.0,
#  3.0,
#  1.0,
#  1.0,
#  3.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  54.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  53.0,
#  54.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  70.0,
#  60.0,
#  60.0,
#  0.67,
#  57.0,
#  54.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  0.83,
#  74.0]

# %%
ind1=titanic_data['Age']>Up_lim
titanic_data.loc[ind1].index
titanic_data.drop(titanic_data.loc[ind1].index,inplace=True)

# %%
plt.boxplot(titanic_data['Age'])
plt.title('box plot of Age')
# Out:
# Text(0.5, 1.0, 'box plot of Age')

# %%
plt.boxplot(titanic_data['Pclass'])
plt.title('box plot of Pclass')
# Out:
# Text(0.5, 1.0, 'box plot of Pclass')

# %%
Q1= np.percentile(titanic_data['Pclass'], 25, interpolation='midpoint')
Q2= np.percentile(titanic_data['Pclass'], 50, interpolation='midpoint')
Q3= np.percentile(titanic_data['Pclass'], 75, interpolation='midpoint')
IQR=Q3-Q1
Low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR

# %%
outlier=[]
for x in titanic_data['Pclass']:
    if((x>Up_lim) or (x<Low_lim)):
        outlier.append(x)

# %%
ind1=titanic_data['Pclass']>Up_lim
titanic_data.loc[ind1].index
# Out:
# Int64Index([], dtype='int64')

# %%
plt.boxplot(titanic_data['Pclass'])
plt.title('box plot of Pclass')
# Out:
# Text(0.5, 1.0, 'box plot of Pclass')

# %% [markdown]
# # 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
titanic_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
a=titanic_data.Survived.value_counts().plot(kind='bar')
a.set_xlabel('survived or not')
a.set_ylabel('passenger')
# Out:
# Text(0, 0.5, 'passenger')

# %%
b=titanic_data.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
c=pd.get_dummies(b)

# %%
c
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500           0         1
# 1           1       1  38.0      1      0  71.2833           1         0
# 2           1       3  26.0      0      0   7.9250           1         0
# 3           1       1  35.0      1      0  53.1000           1         0
# 4           0       3  35.0      0      0   8.0500           0         1
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000           0         1
# 887         1       1  19.0      0      0  30.0000           1         0
# 888         0       3   NaN      1      2  23.4500           1         0
# 889         1       1  26.0      0      0  30.0000           0         1
# 890         0       3  32.0      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# ...

# %%
corrmatrix=c.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corrmatrix,vmin=-2,vmax=1,linewidth=2,annot=True)
# Out:
# <AxesSubplot:>

# %%
y=c['Survived']
x=c.drop(['Survived'],axis=1)

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  Sex_female  \
# count  891.000000  714.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208    0.352413
# std      0.836071   14.526497    1.102743    0.806057   49.693429    0.477990
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200    0.000000
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#          Sex_male  Embarked_C  Embarked_Q  Embarked_S
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.647587    0.188552    0.086420    0.722783
# std      0.477990    0.391372    0.281141    0.447876
# ...

# %%
#minmax scaling
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
x=minmax.fit_transform(x)
x=pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  891.000000  714.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.654321    0.367921    0.065376    0.063599    0.062858    0.352413
# std      0.418036    0.182540    0.137843    0.134343    0.096995    0.477990
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.247612    0.000000    0.000000    0.015440    0.000000
# 50%      1.000000    0.346569    0.000000    0.000000    0.028213    0.000000
# 75%      1.000000    0.472229    0.125000    0.000000    0.060508    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8           9
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.647587    0.188552    0.086420    0.722783
# std      0.477990    0.391372    0.281141    0.447876
# ...
